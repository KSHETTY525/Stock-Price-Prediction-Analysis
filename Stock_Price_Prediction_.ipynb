# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt

stock = "POWERGRID.NS"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2024, 11, 1)

df = yf.download(stock, start, end)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    32.545422    35.424689    26.900117    29.051480    855215656
# 2007-10-08    30.879345    33.645383    30.685236    33.645383    126671715
# 2007-10-09    32.982170    33.273331    29.229417    30.895509    116725709
# 2007-10-10    33.289505    33.968883    32.998344    33.839477     67931378
# 2007-10-11    37.009911    38.821585    32.998349    38.821585    106320954
# ...                 ...          ...          ...          ...          ...
# 2024-10-25   307.732239   313.286633   305.247396   313.286633     12979410
# 2024-10-28   310.168365   312.263463   302.811258   306.465456      9610615
# 2024-10-29   312.360901   312.994319   306.124408   308.024603     15856332
# 2024-10-30   310.314575   317.087006   308.657993   310.411997     14498110
# ...

# %%
df.head()
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    32.545422    35.424689    26.900117    29.051480    855215656
# 2007-10-08    30.879345    33.645383    30.685236    33.645383    126671715
# 2007-10-09    32.982170    33.273331    29.229417    30.895509    116725709
# 2007-10-10    33.289505    33.968883    32.998344    33.839477     67931378
# 2007-10-11    37.009911    38.821585    32.998349    38.821585    106320954

# %%
df.shape
# Out:
# (4208, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4208 entries, 2007-10-05 to 2024-10-31
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   4208 non-null   float64
#  1   (High, POWERGRID.NS)    4208 non-null   float64
#  2   (Low, POWERGRID.NS)     4208 non-null   float64
#  3   (Open, POWERGRID.NS)    4208 non-null   float64
#  4   (Volume, POWERGRID.NS)  4208 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 197.2 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4208.000000  4208.000000  4208.000000  4208.000000  4.208000e+03
# mean      79.483549    80.517027    78.462750    79.520589  1.188963e+07
# std       63.570576    64.313382    62.779670    63.552224  2.061999e+07
# min       19.001738    20.312202    17.036041    20.213917  0.000000e+00
# 25%       36.529123    37.105434    35.989635    36.566529  4.799653e+06
# 50%       55.504944    56.145821    54.762119    55.611505  8.344398e+06
# 75%       83.112982    84.105051    82.127448    83.135585  1.362032e+07
# max      356.113861   356.893408   348.074624   354.749603  8.552157e+08

# %%
df = df.reset_index()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv("powergrid.csv")

# %%
data01 = pd.read_csv("powergrid.csv")

# %%
data01.head()
# Out:
#     Price        Date               Close                High  \
# 0  Ticker         NaN        POWERGRID.NS        POWERGRID.NS
# 1       0  2007-10-05    32.5454216003418    35.4246891776911
# 2       1  2007-10-08  30.879344940185547   33.64538338795362
# 3       2  2007-10-09   32.98217010498047   33.27333102819074
# 4       3  2007-10-10   33.28950500488281  33.968883374439955
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1   26.90011689528922  29.051480080819935     855215656
# 2  30.685236132145377   33.64538338795362     126671715
# 3  29.229417128249786  30.895508777439975     116725709
# 4   32.99834410019465   33.83947682149577      67931378

# %%
df.head()
# Out:
# Price        Date        Close         High          Low         Open  \
# Ticker            POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0      2007-10-05    32.545422    35.424689    26.900117    29.051480
# 1      2007-10-08    30.879345    33.645383    30.685236    33.645383
# 2      2007-10-09    32.982170    33.273331    29.229417    30.895509
# 3      2007-10-10    33.289505    33.968883    32.998344    33.839477
# 4      2007-10-11    37.009911    38.821585    32.998349    38.821585
#
# Price        Volume
# Ticker POWERGRID.NS
# 0         855215656
# 1         126671715
# 2         116725709
# 3          67931378
# 4         106320954

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 1)
plt.title(f'{stock} Closing prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.title(f'{stock} Opening prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume', linewidth = 2)
plt.title(f'{stock} Volume over time')
plt.legend()
plt.show()

# %%
# Moving Average
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# moving average for last 5 days -> null null null null 30.0 40.0 50.0

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[2:7])/5)
# Out:
# 50.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# Ticker  POWERGRID.NS
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 4203      324.993563
# 4204      325.235133
# 4205      325.471086
# 4206      325.670629
# 4207      325.807061
#
# [4208 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1, color='purple')
plt.plot(ma100, label = f'{stock} Moving Average 100 Price', linewidth = 1, color='orange')
plt.plot(ma200, label = f'{stock} Moving Average 200 Price', linewidth = 1, color='green')
plt.legend()
plt.show()

# %%
ema100 = df.Close.ewm(span=100, adjust = False).mean()

# %%
ema200 = df['Close'].ewm(span=200, adjust = False).mean()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1, color='purple')
plt.plot(ema100, label = f'{stock} Exp. Moving Average 100 Price', linewidth = 1, color='orange')
plt.plot(ema200, label = f'{stock} Exp. Moving Average 200 Price', linewidth = 1, color='green')
plt.legend()
plt.show()

# %%
# Training & Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (2945, 1)

# %%
data_testing.shape
# Out:
# (1263, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.19808597],
#        [0.17371842],
#        [0.20447372],
#        ...,
#        [0.90774407],
#        [0.86000386],
#        [0.87299663]])

# %%
data_training_array.shape[0]
# Out:
# 2945

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train  = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2845, 100, 1)

# %%
# Model Building
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %% [markdown]
# LSTM Input -> 3D Array (batch_size, time_steps, seq_len)
# LSTM 2D OR 3D
# 2D -> (batch_sizem units)
# 3D -> (batch_size, time_steps, units)

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# ...
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 89/89 [==============================] - 17s 159ms/step - loss: 0.0287
# Epoch 2/50
# 89/89 [==============================] - 15s 172ms/step - loss: 0.0078
# Epoch 3/50
# 89/89 [==============================] - 17s 191ms/step - loss: 0.0072
# Epoch 4/50
# 89/89 [==============================] - 18s 199ms/step - loss: 0.0073
# Epoch 5/50
# 89/89 [==============================] - 20s 229ms/step - loss: 0.0056
# Epoch 6/50
# 89/89 [==============================] - 20s 226ms/step - loss: 0.0056
# Epoch 7/50
# 89/89 [==============================] - 17s 195ms/step - loss: 0.0055
# Epoch 8/50
# 89/89 [==============================] - 19s 211ms/step - loss: 0.0052
# Epoch 9/50
# 89/89 [==============================] - 19s 215ms/step - loss: 0.0047
# Epoch 10/50
# 89/89 [==============================] - 18s 207ms/step - loss: 0.0049
# Epoch 11/50
# 89/89 [==============================] - 18s 207ms/step - loss: 0.0046
# Epoch 12/50
# ...

# %%
past_100_days = data_training.tail(100)

# %%
#final_df = past_100_days.append(data_testing, ignore_index = True)
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()
# Out:
# Ticker  POWERGRID.NS
# 0          76.105629
# 1          77.657143
# 2          77.922539
# 3          77.759232
# 4          78.208344

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1263, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 40/40 [==============================] - 2s 36ms/step

# %%
y_predicted.shape
# Out:
# (1263, 1)

# %%
scaler.scale_
# Out:
# array([0.00339719])

# %%
scaler_factor = 1 / 0.0035166
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('stock_dl_model.h5')
